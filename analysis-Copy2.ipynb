# %%
import pandas as pd
import numpy as np
# from jupDeep import *
import hashlib


'''
    we drop the columns we are not working with
'''
df = pd.read_csv('dataBlock_new.csv')
df = df.drop(['elementHeight', 'elementWidth','element_id','rap_size'], axis=1)

print('finisat')

# df
# Out:
# finisat

# %%
res = df[['theme','block']]
ways = []
for ind, row in res.iterrows():
    way = row['theme'] +'/'+ row['block']  
    ways += [way]

df['ways'] = ways

df.drop(['theme', 'block'], axis=1, inplace=True )
df
# print(f'finisat : denumiri unica de blocuri : { len( df['ways'].unique() ) }')
# Out:
#       globalBlockHeight  total_elements   x_orig   y_orig    x_end    y_end  \
# 0                 894.0              10  47.1875  15.8750  74.3750  35.6875
# 1                 894.0              10  11.5625  15.8750  38.7500  35.6875
# 2                 894.0              10  47.1875  38.2500  74.3750  40.1250
# 3                 894.0              10  47.1875  42.3750  74.3750  46.5000
# 4                 894.0              10  47.1875  48.2500  61.4375  49.0625
# ...                 ...             ...      ...      ...      ...      ...
# 6869              716.0              17  23.4375   4.3750  56.5625   5.5000
# 6870              550.0               4  44.6875   9.6875  70.9375  28.2500
# 6871              550.0               4   9.0625  16.6875  35.3125  28.5000
# 6872              550.0               4   9.0625   9.6875  38.7500  13.5625
# 6873              550.0               4   9.0625   5.0000  38.7500   6.3750
#
#        type                                               ways
# 0     image  zephyr-blocks/title_with_call_to_action_on_the...
# 1     image  zephyr-blocks/title_with_call_to_action_on_the...
# 2      text  zephyr-blocks/title_with_call_to_action_on_the...
# 3      text  zephyr-blocks/title_with_call_to_action_on_the...
# 4      text  zephyr-blocks/title_with_call_to_action_on_the...
# ...     ...                                                ...
# 6869   text  fiji-blocks/3_columns_-_title_with_boxed_text_...
# 6870   text  fiji-blocks/2_columns_-_long_paragraph_with_ti...
# 6871   text  fiji-blocks/2_columns_-_long_paragraph_with_ti...
# 6872   text  fiji-blocks/2_columns_-_long_paragraph_with_ti...
# 6873   text  fiji-blocks/2_columns_-_long_paragraph_with_ti...
#
# [6874 rows x 8 columns]

# %%
w = 50
h = 50

'''
    which columns will be divided by how much. If the column has the value None, it will not be divided
'''
col_div = {
           'globalBlockHeight' : h, 
           'x_orig': w, 
           'y_orig': h,
           'x_end': w,
           'y_end': h
          }

df_new = df.copy()
''' divizarea blocului in sub-blocuri mai mici de marimea w*h'''
for col_key in col_div:
    if col_div[col_key] != None:
        df_new[col_key] = df_new[col_key]/col_div[col_key]
        df_new[col_key] = df_new[col_key].apply(np.floor)

print('finisat')


df_new
# Out:
# finisat
#       globalBlockHeight  total_elements  x_orig  y_orig  x_end  y_end   type  \
# 0                  17.0              10     0.0     0.0    1.0    0.0  image
# 1                  17.0              10     0.0     0.0    0.0    0.0  image
# 2                  17.0              10     0.0     0.0    1.0    0.0   text
# 3                  17.0              10     0.0     0.0    1.0    0.0   text
# 4                  17.0              10     0.0     0.0    1.0    0.0   text
# ...                 ...             ...     ...     ...    ...    ...    ...
# 6869               14.0              17     0.0     0.0    1.0    0.0   text
# 6870               11.0               4     0.0     0.0    1.0    0.0   text
# 6871               11.0               4     0.0     0.0    0.0    0.0   text
# 6872               11.0               4     0.0     0.0    0.0    0.0   text
# 6873               11.0               4     0.0     0.0    0.0    0.0   text
#
#                                                    ways
# 0     zephyr-blocks/title_with_call_to_action_on_the...
# 1     zephyr-blocks/title_with_call_to_action_on_the...
# 2     zephyr-blocks/title_with_call_to_action_on_the...
# 3     zephyr-blocks/title_with_call_to_action_on_the...
# 4     zephyr-blocks/title_with_call_to_action_on_the...
# ...                                                 ...
# 6869  fiji-blocks/3_columns_-_title_with_boxed_text_...
# 6870  fiji-blocks/2_columns_-_long_paragraph_with_ti...
# 6871  fiji-blocks/2_columns_-_long_paragraph_with_ti...
# 6872  fiji-blocks/2_columns_-_long_paragraph_with_ti...
# 6873  fiji-blocks/2_columns_-_long_paragraph_with_ti...
#
# [6874 rows x 8 columns]

# %%
''' crearea hash pentru fiecare bloc'''

ways_uniq = df['ways'].unique()
params_uniq = ['x_orig','y_orig', 'x_end', 'y_end', 'type'] # modifica dupa necesitate globalBlockHeight
infoBlocks = {}

df_new['bl_hash'] =''
count = 0
for way in ways_uniq:
    cond_way = df_new['ways'] == way
    bl = df_new.loc[ cond_way, : ]
    count += len(bl)
    block_item = bl[params_uniq]
    block_item = np.concatenate(block_item.values)
    
    block_item = [ str(el) for el in block_item ]
    block_item = ''.join( block_item )
    bl_hash = hashlib.sha256(block_item.encode('utf-8')).hexdigest()
    infoBlocks[way] = bl_hash
    df_new.loc[df_new['ways'] == way ,'bl_hash'] = bl_hash

print(f'finisat : blocuri: {len(ways_uniq)} : elemete {count}')
df_new[:7]
# Out:
# finisat : blocuri: 596 : elemete 6874
#    globalBlockHeight  total_elements  x_orig  y_orig  x_end  y_end   type  \
# 0               17.0              10     0.0     0.0    1.0    0.0  image
# 1               17.0              10     0.0     0.0    0.0    0.0  image
# 2               17.0              10     0.0     0.0    1.0    0.0   text
# 3               17.0              10     0.0     0.0    1.0    0.0   text
# 4               17.0              10     0.0     0.0    1.0    0.0   text
# 5               17.0              10     0.0     0.0    0.0    0.0   text
# 6               17.0              10     0.0     0.0    0.0    0.0   text
#
#                                                 ways  \
# 0  zephyr-blocks/title_with_call_to_action_on_the...
# 1  zephyr-blocks/title_with_call_to_action_on_the...
# 2  zephyr-blocks/title_with_call_to_action_on_the...
# 3  zephyr-blocks/title_with_call_to_action_on_the...
# 4  zephyr-blocks/title_with_call_to_action_on_the...
# 5  zephyr-blocks/title_with_call_to_action_on_the...
# 6  zephyr-blocks/title_with_call_to_action_on_the...
#
#                                              bl_hash
# 0  620ba21dee2772ac1ff551279d80c2663f3f0e45942041...
# 1  620ba21dee2772ac1ff551279d80c2663f3f0e45942041...
# 2  620ba21dee2772ac1ff551279d80c2663f3f0e45942041...
# 3  620ba21dee2772ac1ff551279d80c2663f3f0e45942041...
# 4  620ba21dee2772ac1ff551279d80c2663f3f0e45942041...
# 5  620ba21dee2772ac1ff551279d80c2663f3f0e45942041...
# 6  620ba21dee2772ac1ff551279d80c2663f3f0e45942041...

# %%
'''crearea hash pentru fiecare element'''

rows = [ el for i, el in df_new[['x_orig','y_orig','x_end','y_end','type']].iterrows()  ]
el_hash =[]
for row in rows:
    row_str = [ str(el) for el in row.values]
    row_str = ''.join(row_str)
    row_hash = hashlib.sha256(row_str.encode('utf-8')).hexdigest()
    el_hash += [row_hash]
    

df_new['el_hash'] = el_hash

print(f'finisat : hash elements : {len(el_hash)}')
df_new
# Out:
# finisat : hash elements : 6874
#       globalBlockHeight  total_elements  x_orig  y_orig  x_end  y_end   type  \
# 0                  17.0              10     0.0     0.0    1.0    0.0  image
# 1                  17.0              10     0.0     0.0    0.0    0.0  image
# 2                  17.0              10     0.0     0.0    1.0    0.0   text
# 3                  17.0              10     0.0     0.0    1.0    0.0   text
# 4                  17.0              10     0.0     0.0    1.0    0.0   text
# ...                 ...             ...     ...     ...    ...    ...    ...
# 6869               14.0              17     0.0     0.0    1.0    0.0   text
# 6870               11.0               4     0.0     0.0    1.0    0.0   text
# 6871               11.0               4     0.0     0.0    0.0    0.0   text
# 6872               11.0               4     0.0     0.0    0.0    0.0   text
# 6873               11.0               4     0.0     0.0    0.0    0.0   text
#
#                                                    ways  \
# 0     zephyr-blocks/title_with_call_to_action_on_the...
# 1     zephyr-blocks/title_with_call_to_action_on_the...
# 2     zephyr-blocks/title_with_call_to_action_on_the...
# 3     zephyr-blocks/title_with_call_to_action_on_the...
# 4     zephyr-blocks/title_with_call_to_action_on_the...
# ...                                                 ...
# 6869  fiji-blocks/3_columns_-_title_with_boxed_text_...
# 6870  fiji-blocks/2_columns_-_long_paragraph_with_ti...
# 6871  fiji-blocks/2_columns_-_long_paragraph_with_ti...
# 6872  fiji-blocks/2_columns_-_long_paragraph_with_ti...
# 6873  fiji-blocks/2_columns_-_long_paragraph_with_ti...
#
#                                                 bl_hash  \
# 0     620ba21dee2772ac1ff551279d80c2663f3f0e45942041...
# 1     620ba21dee2772ac1ff551279d80c2663f3f0e45942041...
# 2     620ba21dee2772ac1ff551279d80c2663f3f0e45942041...
# 3     620ba21dee2772ac1ff551279d80c2663f3f0e45942041...
# 4     620ba21dee2772ac1ff551279d80c2663f3f0e45942041...
# ...                                                 ...
# 6869  bf3d03bcef7e9b91efc80014cab133a91a3400765a85db...
# 6870  cff8e89836b09bc7de5d9b1cc426edb488701dc4c917c5...
# 6871  cff8e89836b09bc7de5d9b1cc426edb488701dc4c917c5...
# 6872  cff8e89836b09bc7de5d9b1cc426edb488701dc4c917c5...
# 6873  cff8e89836b09bc7de5d9b1cc426edb488701dc4c917c5...
#
#                                                 el_hash
# 0     21479488818f5c9d3d6e692896c5db2cfdff23cf5e5c56...
# 1     04e9b73fef1669ff9830aae3621ffcf3d08386d0c5c27b...
# 2     ca0ece82cfd11f50539df1dbe798878b13caedbfa4ab2a...
# 3     6f4b0605407d3d8652631306f5dc9da5c5b77a79bc005c...
# 4     bd3d09e30ecf06c6a8490c1a546794c83af901e91de1c0...
# ...                                                 ...
# 6869  75d4313f9e083c6ede27f1b7e23bd6fa05e379097d42e1...
# 6870  66651bd10e9ba62e040db72cec64eea4c737087cf0b708...
# 6871  45f6fd1618d34f1613ed88154cd7cede00fd364a7b037f...
# 6872  f73505f8dc3751857f0d1110ee95faa74d8085e34d390e...
# 6873  a8fbced4ac2a7f6a594f48d357e4e6d37cf6759f4eb28d...
#
# [6874 rows x 10 columns]

# %%
from datetime import datetime
print("Current Time =", datetime.now().strftime("%H:%M:%S"))
 
f = open('data_aproxim.csv','a')
cols = ['block_1','block_2', 'num_elem_1','num_elem_2','com_elem','percent_1','percent_2']
cols = ';'.join(cols)
f.write(cols)
f.write("\n")
f.close()

bls_ways = df_new['ways'] # all ways blocks
ways1 = []
ways2 = []

total_elements1 = []
total_elements2 = []

com_elem = []

percent_1 = []
percent_2 = []

count = 0
was = []
for bl_w in df_new['ways'].unique():
    count += 1
    if count % 10 == 0:
        print(f'sau procesat {count} blocuri \n')
    
    '''info despre blocul care va fi comparat cu celelalte blocuri'''
    bl = df_new.loc[ df_new['ways'] == bl_w , : ]
    els_hash = np.array(bl['el_hash'])
    bl_te = int( bl['total_elements'].unique()[0] )

#     print(els_hash, els_te, bl_w, sep='\n')
    '''list cu blocurile cu care va fi comparat blocul de mai sus'''
    
    other_bls_w = df_new.loc[ df_new['ways'] != bl_w , 'ways'].unique()
    was += [bl_w]
    for o_bl_w in other_bls_w:
        
        if o_bl_w in was:
            continue
        
        o_bl = df_new.loc[ (df_new['ways'] == o_bl_w ), : ]
        o_els_hash = np.array( o_bl['el_hash'] )
        o_bl_te = int(o_bl['total_elements'].unique()[0])

#     print(o_els_hash, o_els_theme, o_els_block, o_way, sep='\n')
        com_els = np.intersect1d(els_hash, o_els_hash)
        
        if len(com_els) > 0:
            com_els = len(com_els)
            try:
                ways1 += [bl_w]
                ways2 += [o_bl_w]

                total_elements1 += [bl_te]
                total_elements2 += [o_bl_te]

                com_elem += [com_els]
                
                aprox_1 = round( com_els / bl_te * 100, 1)
                percent_1 += [aprox_1]

                aprox_2 = round( com_els / o_bl_te * 100, 1)
                percent_2 += [aprox_2]

                row = [bl_w, o_bl_w, bl_te, o_bl_te, com_els, aprox_1, aprox_2]
                row = [ str(el) for el in row ]
                row = ';'.join(row)
                print(row)
                f = open('data_aproxim.csv','a')
                f.write(row)
                f.write("\n")
                f.close()
                
            except:
                log = open('log_da.csv','a')
                log.write(f'{bl_w},{o_bl_w}')
                log.write("\n")
                log.close() 
            

            
            

# print('finisat')
# Out:
# Current Time = 09:17:22
# verificate al 1
# zephyr-blocks/title_with_call_to_action_on_the_top_and_2_cards_with_image_and_text_on_the_bottom.json
#
# verificate al 2
# zephyr-blocks/text_on_the_top_and_social_media_links_on_the_bottom.json
#
# verificate al 3
# zephyr-blocks/text_with_link_left_image_with_title_centred_and_text_with_link_right.json
#
# verificate al 4
# zephyr-blocks/3_rows_with_image_and_text_and_call_to_actions.json
#
# verificate al 5
# zephyr-blocks/text_with_call_to_action_left_and_image_with_4_text_columns_right.json
#
# verificate al 6
# zephyr-blocks/2_images_and_display_text_with_call_to_action.json
#
# verificate al 7
# zephyr-blocks/display_title_and_quote_on_top_and_full_weight_image_and_text_on_bottom.json
#
# verificate al 8
# zephyr-blocks/image_with_text_left_and_text_with_image_right.json
#
# verificate al 9
# zephyr-blocks/2_images_overlap_left_and_text_right.json
#
# verificate al 10
# zephyr-blocks/display_text_with_2_images_left_and_text_right.json
#
# verificate al 11
# zephyr-blocks/2_cards_with_text_and_image_on_the_top_and_video_on_the_bottom.json
#
# zephyr-blocks/2_cards_with_text_and_image_on_the_top_and_video_on_the_bottom.json;zephyr-blocks/title_and_5_cards_with_image_and_text.json;12;21;1;8.3;4.8
# verificate al 12
# zephyr-blocks/text_with_call_to_action_left_and_image_right.json
#
# verificate al 13
# zephyr-blocks/5_cards_with_image_and_text_and_call_to_action.json
#
# zephyr-blocks/5_cards_with_image_and_text_and_call_to_action.json;zephyr-blocks/text_on_the_top_and_6_images_on_the_bottom.json;17;9;1;5.9;11.1
# verificate al 14
# zephyr-blocks/big_image_left_and_6_text_columns_right.json
#
# verificate al 15
# zephyr-blocks/image_with_text_left_and_centred_text_and_image_right.json
#
# verificate al 16
# zephyr-blocks/display_text_with_call_to_action_and_image_collage.json
#
# verificate al 17
# zephyr-blocks/text_on_the_top_and_2_image_colages_in_the_midle_and_text_on_the_bottom.json
#
# verificate al 18
# zephyr-blocks/title_and_5_cards_with_image_and_text.json
#
# verificate al 19
# zephyr-blocks/text_on_the_top_and_6_images_on_the_bottom.json
#
# verificate al 20
# zephyr-blocks/title_and_3_rows_with_image_and_text.json
#
# verificate al 21
# cannes-blocks/title_with_links_left_and_autoplay_video_with_text_and_link_right.json
#
# cannes-blocks/title_with_links_left_and_autoplay_video_with_text_and_link_right.json;mono-blocks/14_text.json;14;12;1;7.1;8.3
# cannes-blocks/title_with_links_left_and_autoplay_video_with_text_and_link_right.json;lyra-blocks/3_columns_-_full_haight_image_left_and_3_call_to_actions.json;14;13;1;7.1;7.7
# verificate al 22
# cannes-blocks/2_autoplay_video_and_text_with_link.json
#
# verificate al 23
# cannes-blocks/4_cards_with_image_and_text.json
#
# verificate al 24
# cannes-blocks/2_cards_with_text_and_4_videos_with_title.json
#
# verificate al 25
# cannes-blocks/_2_text_columns_with_call_to_action_left_and_image_right.json
#
# verificate al 26
# cannes-blocks/boxed_image_with_text_and_call_to_action_left_and_text_with_link_right.json
#
# verificate al 27
# cannes-blocks/video_left_and_text_with_link_right.json
#
# verificate al 28
# cannes-blocks/title_and_link_on_top_and_mosaic_grid_of_3_videos_bottom.json
#
# verificate al 29
# cannes-blocks/text_left_and_logos_right.json
#
# verificate al 30
# cannes-blocks/big_video_and_text_left_and_2_small_images_with_text_right.json
#
# verificate al 31
# cannes-blocks/title_with_paragraph_left_and_video_with_text_right.json
#
# verificate al 32
# cannes-blocks/video_on_top_and_text_on_bottom.json
#
# verificate al 33
# cannes-blocks/mosaic_grid_of_4_videos.json
#
# verificate al 34
# cannes-blocks/2_cards_-_video_with_text_and_link.json
#
# verificate al 35
# cannes-blocks/text_and_links_left_and_mosaic_grid_of_3_videos_right.json
#
# verificate al 36
# cannes-blocks/full-height_image_left_and_full-height_autoplay_video_right.json
#
# verificate al 37
# cannes-blocks/fullscreen_video_on_top_and_text_on_bottom.json
#
# verificate al 38
# cannes-blocks/2_columns_with_text_and_1_with_socila_media_links.json
#
# cannes-blocks/2_columns_with_text_and_1_with_socila_media_links.json;milea-blocks/title_with_line_-_2_text_columns_and_1_image.json;13;11;1;7.7;9.1
# verificate al 39
# rosemary-blocks/3_images_with_text_and_1_call_to_action.json
#
# verificate al 40
# rosemary-blocks/title_with_6_images_and_call_to_action.json
#
# verificate al 41
# rosemary-blocks/image_with_link_left_and_6_text_blocks.json
#
# verificate al 42
# rosemary-blocks/video_left_and_text_right.json
#
# verificate al 43
# rosemary-blocks/3_image_cards_with_text_on_them.json
#
# verificate al 44
# rosemary-blocks/image_left_with_boxed_text_in_center_and_image_right.json
#
# verificate al 45
# rosemary-blocks/title_and_2_images_with_text.json
#
# verificate al 46
# rosemary-blocks/title_and_2_columns_with_image_and_text_and_call_to_action.json
#
# verificate al 47
# rosemary-blocks/fullscreen_image_with_boxed_text_and_call_to_action.json
#
# verificate al 48
# rosemary-blocks/text_columns_with_link_left_and_image_right.json
#
# verificate al 49
# rosemary-blocks/text_with_call_to_action_left_and_image_right_inside_the_box.json
#
# verificate al 50
# rosemary-blocks/text_with_social_media_links_left_and_3_images_with_text_right.json
#
# verificate al 51
# rosemary-blocks/text_with_call_to_action_top_and_4_images_bottom.json
#
# verificate al 52
# rosemary-blocks/image_with_call_to_action_left_and_text_right.json
#
# verificate al 53
# rosemary-blocks/3_columns_-_rounded_image_with_text.json
#
# verificate al 54
# rosemary-blocks/text_left_and_text_with_image_right.json
#
# verificate al 55
# rosemary-blocks/4_rows_-_title_with_paragraph.json
#
# verificate al 56
# rosemary-blocks/image_with_text_and_links_on_the_accent_background.json
#
# verificate al 57
# rosemary-blocks/text_left_with_image_right_on_accent_background.json
#
# verificate al 58
# rosemary-blocks/text_with_call_to_action_left_and_2_images_right.json
#
# verificate al 59
# narcisse-blocks/2_columns_masonry_grid_image_with_title_and_subtitle.json
#
# verificate al 60
# narcisse-blocks/title_with_big_image_on_left_divided_by_line_and_text_list_on_right.json
#
# verificate al 61
# narcisse-blocks/4_image_cards_with_title_and_description.json
#
# verificate al 62
# narcisse-blocks/3_columns_text_with_call_to_action.json
#
# verificate al 63
# narcisse-blocks/3_columns_text_divided_by_lines_with_title_and_overline.json
#
# narcisse-blocks/3_columns_text_divided_by_lines_with_title_and_overline.json;ember-blocks/full_screen_image_with_big_title_and_small_text_and_button.json;24;6;1;4.2;16.7
# narcisse-blocks/3_columns_text_divided_by_lines_with_title_and_overline.json;crowd-blocks/2_rows_-_cards_with_image_and_accent_color_with_text.json;24;21;1;4.2;4.8
# narcisse-blocks/3_columns_text_divided_by_lines_with_title_and_overline.json;milea-blocks/2_rows_-_image_with_title_paragraph_and_image_with_lines.json;24;13;1;4.2;7.7
# narcisse-blocks/3_columns_text_divided_by_lines_with_title_and_overline.json;fiji-blocks/3_columns_-_boxed_text_on_sides_and_1_image_at_center.json;24;12;1;4.2;8.3
# verificate al 64
# narcisse-blocks/4_columns_-_2_rows_images_with_title_and_subtitle.json
#
# verificate al 65
# narcisse-blocks/1_image_left_with_paragraph_in_middle_and_list_of_text_on_right.json
#
# verificate al 66
# narcisse-blocks/title_and_call_to_action_-_2_columns_big_images_with_title_and_subtitle.json
#
# verificate al 67
# narcisse-blocks/big_image_on_left_with_titles_and_description_on_right_with_call_to_action.json
#
# verificate al 68
# narcisse-blocks/3_text_columns_-_title_and_subtitle.json
#
# verificate al 69
# narcisse-blocks/titles_and_paragraph_with_call_to_action_on_left_with_2_text_list_and_image.json
#
# verificate al 70
# narcisse-blocks/2_rows_with_images_with_description_and_call_to_action.json
#
# narcisse-blocks/2_rows_with_images_with_description_and_call_to_action.json;nessa-blocks/3_text_columns_with_images.json;26;21;1;3.8;4.8
# narcisse-blocks/2_rows_with_images_with_description_and_call_to_action.json;nomade-blocks/2_columns_images_with_title_and_paragraph.json;26;16;1;3.8;6.2
# narcisse-blocks/2_rows_with_images_with_description_and_call_to_action.json;velvet-blocks/1_text_column_left_and_1_image_column_right.json;26;12;1;3.8;8.3
# verificate al 71
# narcisse-blocks/big_paragraph_left_and_description_with_titles_on_right.json
#
# verificate al 72
# narcisse-blocks/multiple_images_grid_with_text_over_and_title.json
#
# narcisse-blocks/multiple_images_grid_with_text_over_and_title.json;narcisse-blocks/2_rows_of_4_columns_with_title.json;14;21;1;7.1;4.8
# verificate al 73
# narcisse-blocks/title_with_paragraph_on_left_with_image_and_call_to_action_on_right.json
#
# verificate al 74
# narcisse-blocks/2_rows_of_4_columns_with_title.json
#
# verificate al 75
# narcisse-blocks/1_featured_image_with_description_and_3_images_with_description.json
#
# verificate al 76
# narcisse-blocks/5_columns_text_assymetric_with_lines_and_1_image.json
#
# verificate al 77
# narcisse-blocks/2_text_columns_divided_by_line_with_call_to_action.json
#
# verificate al 78
# narcisse-blocks/split_screen_-_full_height_image_left_and_3_images_overlapping_on_right_with_title.json
#
# narcisse-blocks/split_screen_-_full_height_image_left_and_3_images_overlapping_on_right_with_title.json;mono-blocks/66_links.json;7;7;1;14.3;14.3
# verificate al 79
# cotton-blocks/3_links_3_columns_with_title.json
#
# verificate al 80
# cotton-blocks/2_text_columns_with_line.json
#
# verificate al 81
# cotton-blocks/3_columns_with_lines_-_2_images_and_description.json
#
# verificate al 82
# cotton-blocks/boxed_background_image_with_text_over_and_description.json
#
# verificate al 83
# cotton-blocks/quote_with_1_image.json
#
# verificate al 84
# cotton-blocks/1_image_on_right_with_text_o_left_with_accent_background.json
#
# verificate al 85
# cotton-blocks/3_columns_multiple_links_with_description_and_images.json
#
# cotton-blocks/3_columns_multiple_links_with_description_and_images.json;nomade-blocks/title_with_boxed_video_and_description_centered.json;14;7;1;7.1;14.3
# verificate al 86
# cotton-blocks/2_columns_text_with_one_image.json
#
# verificate al 87
# cotton-blocks/3_rows_-_image_with_text_and_call_to_action_alternate.json
#
# verificate al 88
# cotton-blocks/3_columns_with_1_image_at_center_and_2_columns_text.json
#
# verificate al 89
# cotton-blocks/split_screen_multiple_links_with_title.json
#
# verificate al 90
# cotton-blocks/title_with_2_columns_text_list_and_line.json
#
# verificate al 91
# cotton-blocks/boxed_text_on_left_and_links_list_on_right_with_1_image.json
#
# verificate al 92
# cotton-blocks/4_columns_with_outline_and_text.json
#
# verificate al 93
# cotton-blocks/boxed_background_image_with_text_over_and_boxed_text.json
#
# verificate al 94
# cotton-blocks/centered_text_with_quote_and_call_to_action.json
#
# verificate al 95
# cotton-blocks/1_image_right_and_text_on_left_with_call_to_action.json
#
# verificate al 96
# cotton-blocks/boxed_text_on_left_with_image_and_call_to_action.json
#
# verificate al 97
# cotton-blocks/autoplay_fullscreen_video.json
#
# cotton-blocks/autoplay_fullscreen_video.json;mono-blocks/107_video.json;4;4;2;50.0;50.0
# verificate al 98
# evora-blocks/fullscreen_image_with_title_and_social_media_icons.json
#
# evora-blocks/fullscreen_image_with_title_and_social_media_icons.json;mono-blocks/51_links.json;10;5;1;10.0;20.0
# verificate al 99
# evora-blocks/2_boxed_texts_with_full_weight_image.json
#
# verificate al 100
# evora-blocks/image_with_title_left_and_small_image_with_call_to_action_right.json
#
# verificate al 101
# evora-blocks/3_images_and_multiple_links.json
#
# verificate al 102
# evora-blocks/4_images_with_call_to_action.json
#
# verificate al 103
# evora-blocks/boxed_text_left_and_full_weight_image.json
#
# evora-blocks/boxed_text_left_and_full_weight_image.json;mono-blocks/49_links.json;10;5;1;10.0;20.0
# verificate al 104
# evora-blocks/text_left_and_4_images_right.json
#
# verificate al 105
# evora-blocks/fullscreen_image_with_centered_text_and_call_to_action.json
#
# verificate al 106
# evora-blocks/3_images_left_with_multiple_links_right.json
#
# evora-blocks/3_images_left_with_multiple_links_right.json;elise-blocks/1_image_with_display_text_and_1_text_column_left_and_1_text_column_right.json;23;8;1;4.3;12.5
# verificate al 107
# evora-blocks/text_with_call_to_action_left_and_image_right.json
#
# verificate al 108
# evora-blocks/text_left_with_big_image_and_2_small_images_with_text.json
#
# verificate al 109
# evora-blocks/2_images_with_centered_text_column.json
#
# verificate al 110
# evora-blocks/2_columns_-_text_with_call_to_action.json
#
# verificate al 111
# evora-blocks/fullscreen_image_with_3_text_columns.json
#
# evora-blocks/fullscreen_image_with_3_text_columns.json;mono-blocks/19_images.json;15;4;1;6.7;25.0
# evora-blocks/fullscreen_image_with_3_text_columns.json;kaya-blocks/fullscreen_image_with_text.json;15;5;1;6.7;20.0
# evora-blocks/fullscreen_image_with_3_text_columns.json;milea-blocks/fullscreen_background_image_with_title_and_arrow_down.json;15;5;1;6.7;20.0
# verificate al 112
# evora-blocks/2_text_columns_with_centered_logo.json
#
# verificate al 113
# evora-blocks/boxed_text_left_and_full_height_image_right.json
#
# verificate al 114
# evora-blocks/2_images_and_call_to_action.json
#
# verificate al 115
# evora-blocks/text_left_with_3_images_right.json
#
# verificate al 116
# evora-blocks/2_images_with_text_column_and_boxed_text.json
#
# verificate al 117
# evora-blocks/big_image_left_with_3_small_images.json
#
# verificate al 118
# ember-blocks/title_with_4_text_columns.json
#
# verificate al 119
# ember-blocks/9_images_with_text_and_links_and_a_call_to_action.json
#
# verificate al 120
# ember-blocks/full_screen_autoplaying_video_with_text.json
#
# verificate al 121
# ember-blocks/image_with_text_and_call_to_actions_centered.json
#
# verificate al 122
# ember-blocks/title_and_6_small_images.json
#
# verificate al 123
# ember-blocks/2_columns_-_text_with_call_to_action_and_text_with_image.json
#
# verificate al 124
# ember-blocks/text_with_bullet_points_and_call_to_action_left_and_image_right.json
#
# verificate al 125
# ember-blocks/2_columns_-_text_with_image_and_five_bullet_point.json
#
# verificate al 126
# ember-blocks/title_with_4_images_left_and_text_with_call_to_action_right.json
#
# verificate al 127
# ember-blocks/full_height_image_left_and_text_with_social_media_links_right.json
#
# verificate al 128
# ember-blocks/full_height_image_left_and_title_with_6_bullet_points_and_call_to_action.json
#
# verificate al 129
# ember-blocks/2_columns_-_image_on_top_with_text_and_image_on_bottom_with_text.json
#
# verificate al 130
# ember-blocks/full_screen_image_with_big_title_and_small_text_and_button.json
#
# verificate al 131
# ember-blocks/title_and_3_text_columns_and_2_call_to_actions.json
#
# verificate al 132
# ember-blocks/text_with_call_to_action_left_with_image_right.json
#
# verificate al 133
# ember-blocks/big_video_on_the_top_and_2_columns_with_image_and_text.json
#
# verificate al 134
# ember-blocks/text_with_video_left_and_full_height_video_right.json
#
# verificate al 135
# ember-blocks/title_with_one_paragraph_and_3_asimetric_rows_with_image_and_text.json
#
# verificate al 136
# ember-blocks/full_screen_image_with_text_and_call_to_action_on_bottom.json
#
# verificate al 137
# ember-blocks/title_with_2_mirrored_columns_of_text.json
#
# verificate al 138
# ember-blocks/image_with_text_on_the_top_and_text_with_video_on_the_bottom.json
#
# verificate al 139
# ember-blocks/title_and_4_columns_with_image_and_text_and_a_call_to_action.json
#
# verificate al 140
# ember-blocks/title_and_3_cards_with_text_and_call_to_action.json
#
# ember-blocks/title_and_3_cards_with_text_and_call_to_action.json;mono-blocks/78_links.json;22;23;2;9.1;8.7
# verificate al 141
# ember-blocks/text_left_and_map_right.json
#
# verificate al 142
# ember-blocks/text_with_icon_and_call_to_action_left_and_image_right.json
#
# verificate al 143
# mono-blocks/89_links.json
#
# verificate al 144
# mono-blocks/17_text.json
#
# verificate al 145
# mono-blocks/03_text.json
#
# verificate al 146
# mono-blocks/76_links.json
#
# verificate al 147
# mono-blocks/95_links.json
#
# mono-blocks/95_links.json;mono-blocks/57_links.json;13;14;1;7.7;7.1
# verificate al 148
# mono-blocks/101_links.json
#
# verificate al 149
# mono-blocks/26_images.json
#
# mono-blocks/26_images.json;elise-blocks/1_big_image_with_call_to_action_left_and_2_small_images_with_call_to_action_right.json;6;17;1;16.7;5.9
# verificate al 150
# mono-blocks/43_images.json
#
# verificate al 151
# mono-blocks/33_images.json
#
# verificate al 152
# mono-blocks/113_video.json
#
# verificate al 153
# mono-blocks/84_links.json
#
# verificate al 154
# mono-blocks/67_links.json
#
# verificate al 155
# mono-blocks/50_links.json
#
# mono-blocks/50_links.json;mono-blocks/81_links.json;7;15;1;14.3;6.7
# mono-blocks/50_links.json;mono-blocks/36_images.json;7;15;1;14.3;6.7
# mono-blocks/50_links.json;lyra-blocks/fullscreen_image_with_text_left_and_boxed_image_with_text_right.json;7;10;1;14.3;10.0
# verificate al 156
# mono-blocks/98_links.json
#
# verificate al 157
# mono-blocks/18_images.json
#
# verificate al 158
# mono-blocks/81_links.json
#
# mono-blocks/81_links.json;mono-blocks/36_images.json;15;15;1;6.7;6.7
# mono-blocks/81_links.json;crowd-blocks/title_with_framed_image_and_text_list.json;15;13;1;6.7;7.7
# mono-blocks/81_links.json;lyra-blocks/2_columns_-_big_image_with_call_to_action_right_and_small_image_with_call_to_action_on_right.json;15;10;2;13.3;20.0
# verificate al 159
# mono-blocks/49_links.json
#
# verificate al 160
# mono-blocks/36_images.json
#
# mono-blocks/36_images.json;mono-blocks/16_text.json;15;7;1;6.7;14.3
# mono-blocks/36_images.json;lyra-blocks/2_columns_-_title_left_with_link.json;15;6;1;6.7;16.7
# verificate al 161
# mono-blocks/46_images.json
#
# verificate al 162
# mono-blocks/11_text.json
#
# verificate al 163
# mono-blocks/55_links.json
#
# verificate al 164
# mono-blocks/62_links.json
#
# verificate al 165
# mono-blocks/05_text.json
#
# verificate al 166
# mono-blocks/73_links.json
#
# verificate al 167
# mono-blocks/104_links.json
#
# verificate al 168
# mono-blocks/23_images.json
#
# mono-blocks/23_images.json;mono-blocks/13_text.json;11;17;1;9.1;5.9
# mono-blocks/23_images.json;niko-blocks/background_image_with_title_text_on_top_and_4_rows_with_call_to_action.json;11;17;1;9.1;5.9
# mono-blocks/23_images.json;elise-blocks/fullscreen_image_with_title_and_3_columns.json;11;11;1;9.1;9.1
# mono-blocks/23_images.json;faro-blocks/full_height_image_with_call_to_action_and_image_with_call_to_action.json;11;11;1;9.1;9.1
# mono-blocks/23_images.json;lovely-blocks/fullscreen_background_image_-_text_over_and_lines.json;11;7;1;9.1;14.3
# verificate al 169
# mono-blocks/58_links.json
#
# verificate al 170
# mono-blocks/90_links.json
#
# verificate al 171
# mono-blocks/107_video.json
#
# verificate al 172
# mono-blocks/08_text.json
#
# verificate al 173
# mono-blocks/97_links.json
#
# verificate al 174
# mono-blocks/02_text.json
#
# verificate al 175
# mono-blocks/20_images.json
#
# mono-blocks/20_images.json;crowd-blocks/fullscreen_image_background_with_links_and_logo.json;6;15;1;16.7;6.7
# mono-blocks/20_images.json;porto-blocks/fullscreen_background_image_with_multiple_text_columns_and_call_to_action.json;6;17;1;16.7;5.9
# mono-blocks/20_images.json;velvet-blocks/fullscreen_image_with_2_text_columns_and_3_call_to_actions.json;6;14;1;16.7;7.1
# verificate al 176
# mono-blocks/103_links.json
#
# verificate al 177
# mono-blocks/68_links.json
#
# verificate al 178
# mono-blocks/16_text.json
#
# mono-blocks/16_text.json;lyra-blocks/2_columns_-_title_left_with_link.json;7;6;1;14.3;16.7
# verificate al 179
# mono-blocks/74_links.json
#
# verificate al 180
# mono-blocks/52_links.json
#
# verificate al 181
# mono-blocks/65_links.json
#
# mono-blocks/65_links.json;mono-blocks/66_links.json;9;7;1;11.1;14.3
# mono-blocks/65_links.json;faro-blocks/fullscreen_image_with_title_and_call_to_action.json;9;6;1;11.1;16.7
# verificate al 182
# mono-blocks/29_images.json
#
# verificate al 183
# mono-blocks/79_links.json
#
# verificate al 184
# mono-blocks/35_images.json
#
# verificate al 185
# mono-blocks/45_images.json
#
# verificate al 186
# mono-blocks/111_video.json
#
# verificate al 187
# mono-blocks/86_links.json
#
# mono-blocks/86_links.json;mono-blocks/69_links.json;15;14;1;6.7;7.1
# verificate al 188
# mono-blocks/108_video.json
#
# verificate al 189
# mono-blocks/60_links.json
#
# verificate al 190
# mono-blocks/57_links.json
#
# verificate al 191
# mono-blocks/114_video.json
#
# verificate al 192
# mono-blocks/83_links.json
#
# verificate al 193
# mono-blocks/04_text.json
#
# verificate al 194
# mono-blocks/10_text.json
#
# verificate al 195
# mono-blocks/40_images.json
#
# verificate al 196
# mono-blocks/30_images.json
#
# verificate al 197
# mono-blocks/25_images.json
#
# verificate al 198
# mono-blocks/92_links.json
#
# verificate al 199
# mono-blocks/105_video.json
#
# verificate al 200
# mono-blocks/09_text.json
#
# verificate al 201
# mono-blocks/71_links.json
#
# verificate al 202
# mono-blocks/39_images.json
#
# verificate al 203
# mono-blocks/48_links.json
#
# verificate al 204
# mono-blocks/22_images.json
#
# verificate al 205
# mono-blocks/80_links.json
#
# verificate al 206
# mono-blocks/54_links.json
#
# verificate al 207
# mono-blocks/63_links.json
#
# verificate al 208
# mono-blocks/15_text.json
#
# verificate al 209
# mono-blocks/01_text.json
#
# verificate al 210
# mono-blocks/72_links.json
#
# verificate al 211
# mono-blocks/91_links.json
#
# verificate al 212
# mono-blocks/19_images.json
#
# mono-blocks/19_images.json;kaya-blocks/fullscreen_image_with_text.json;4;5;1;25.0;20.0
# mono-blocks/19_images.json;milea-blocks/fullscreen_background_image_with_title_and_arrow_down.json;4;5;1;25.0;20.0
# verificate al 213
# mono-blocks/106_video.json
#
# verificate al 214
# mono-blocks/47_images.json
#
# verificate al 215
# mono-blocks/37_images.json
#
# verificate al 216
# mono-blocks/59_links.json
#
# verificate al 217
# mono-blocks/13_text.json
#
# mono-blocks/13_text.json;faro-blocks/full_height_image_with_call_to_action_and_image_with_call_to_action.json;17;11;1;5.9;9.1
# mono-blocks/13_text.json;june-blocks/2_cards_with_boxed_text_and_image_and_call_to_action.json;17;11;1;5.9;9.1
# verificate al 218
# mono-blocks/77_links.json
#
# verificate al 219
# mono-blocks/88_links.json
#
# verificate al 220
# mono-blocks/07_text.json
#
# verificate al 221
# mono-blocks/32_images.json
#
# verificate al 222
# mono-blocks/100_links.json
#
# verificate al 223
# mono-blocks/42_images.json
#
# verificate al 224
# mono-blocks/94_links.json
#
# verificate al 225
# mono-blocks/112_video.json
#
# verificate al 226
# mono-blocks/85_links.json
#
# verificate al 227
# mono-blocks/27_images.json
#
# verificate al 228
# mono-blocks/99_links.json
#
# verificate al 229
# mono-blocks/66_links.json
#
# mono-blocks/66_links.json;faro-blocks/fullscreen_image_with_title_and_call_to_action.json;7;6;1;14.3;16.7
# verificate al 230
# mono-blocks/51_links.json
#
# verificate al 231
# mono-blocks/61_links.json
#
# verificate al 232
# mono-blocks/56_links.json
#
# verificate al 233
# mono-blocks/109_video.json
#
# verificate al 234
# mono-blocks/38_images.json
#
# verificate al 235
# mono-blocks/24_images.json
#
# verificate al 236
# mono-blocks/115_video.json
#
# verificate al 237
# mono-blocks/82_links.json
#
# verificate al 238
# mono-blocks/14_text.json
#
# mono-blocks/14_text.json;lyra-blocks/3_columns_-_full_haight_image_left_and_3_call_to_actions.json;12;13;1;8.3;7.7
# mono-blocks/14_text.json;lyra-blocks/2_text_columns_with_call_to_actions_and_image_right.json;12;9;1;8.3;11.1
# verificate al 239
# mono-blocks/93_links.json
#
# verificate al 240
# mono-blocks/31_images.json
#
# verificate al 241
# mono-blocks/41_images.json
#
# mono-blocks/41_images.json;faro-blocks/full_height_image_and_call_to_action_left_and_text_column_right.json;15;10;1;6.7;10.0
# verificate al 242
# mono-blocks/70_links.json
#
# verificate al 243
# mono-blocks/102_links.json
#
# verificate al 244
# mono-blocks/44_images.json
#
# verificate al 245
# mono-blocks/06_text.json
#
# verificate al 246
# mono-blocks/34_images.json
#
# verificate al 247
# mono-blocks/69_links.json
#
# verificate al 248
# mono-blocks/12_text.json
#
# verificate al 249
# mono-blocks/96_links.json
#
# verificate al 250
# mono-blocks/75_links.json
#
# verificate al 251
# mono-blocks/28_images.json
#
# verificate al 252
# mono-blocks/53_links.json
#
# verificate al 253
# mono-blocks/64_links.json
#
# verificate al 254
# mono-blocks/110_video.json
#
# verificate al 255
# mono-blocks/87_links.json
#
# mono-blocks/87_links.json;faro-blocks/3_columns_-_images_with_text.json;14;14;1;7.1;7.1
# verificate al 256
# mono-blocks/78_links.json
#
# verificate al 257
# mono-blocks/21_images.json
#
# mono-blocks/21_images.json;porto-blocks/fullscreen_background_image_with_centered_title_and_links.json;4;8;1;25.0;12.5
# verificate al 258
# crowd-blocks/title_with_framed_image_and_text_list.json
#
# verificate al 259
# crowd-blocks/title_and_call_to_action_with_2_columns_images_and_titles.json
#
# verificate al 260
# crowd-blocks/2_rows_-_cards_with_image_and_accent_color_with_text.json
#
# crowd-blocks/2_rows_-_cards_with_image_and_accent_color_with_text.json;milea-blocks/2_rows_-_image_with_title_paragraph_and_image_with_lines.json;21;13;1;4.8;7.7
# crowd-blocks/2_rows_-_cards_with_image_and_accent_color_with_text.json;fiji-blocks/3_columns_-_boxed_text_on_sides_and_1_image_at_center.json;21;12;1;4.8;8.3
# verificate al 261
# crowd-blocks/text_list_with_title_and_image_in_the_right.json
#
# verificate al 262
# crowd-blocks/3_columns_-_images_at_side_with_centered_text.json
#
# crowd-blocks/3_columns_-_images_at_side_with_centered_text.json;crowd-blocks/text_in_left_with_call_to_action_and_two_images_in_the_right.json;6;7;1;16.7;14.3
# verificate al 263
# crowd-blocks/fullscreen_background_image_with_text_and_call_to_action.json
#
# crowd-blocks/fullscreen_background_image_with_text_and_call_to_action.json;osaka-blocks/1_link_-_full_width_image_with_boxed_text.json;7;6;1;14.3;16.7
# verificate al 264
# crowd-blocks/title_with_paragraph_and_small_images_grid.json
#
# crowd-blocks/title_with_paragraph_and_small_images_grid.json;lyra-blocks/call_to_action_right_with_title_and_paragraph.json;7;8;1;14.3;12.5
# verificate al 265
# crowd-blocks/fullscreen_image_background_with_links_and_logo.json
#
# crowd-blocks/fullscreen_image_background_with_links_and_logo.json;porto-blocks/fullscreen_background_image_with_multiple_text_columns_and_call_to_action.json;15;17;1;6.7;5.9
# crowd-blocks/fullscreen_image_background_with_links_and_logo.json;velvet-blocks/fullscreen_image_with_2_text_columns_and_3_call_to_actions.json;15;14;1;6.7;7.1
# verificate al 266
# crowd-blocks/text_in_left_with_call_to_action_and_two_images_in_the_right.json
#
# verificate al 267
# crowd-blocks/autoplay_video_with_framed_text.json
#
# verificate al 268
# crowd-blocks/2_columns_-_text_framed_with_centered_title.json
#
# verificate al 269
# crowd-blocks/3_columns_-_2_text_lines.json
#
# verificate al 270
# crowd-blocks/2_columns_-_image_right_with_title_and_paragraph_in_left.json
#
# verificate al 271
# crowd-blocks/1_column_-_centered_text_with_multiple_images_framed.json
#
# verificate al 272
# crowd-blocks/grid_image_links.json
#
# verificate al 273
# crowd-blocks/3_columns_-_masonry_images_grid_with_title.json
#
# verificate al 274
# crowd-blocks/2_cards_with_image_with_cta_and_text_framed.json
#
# verificate al 275
# crowd-blocks/_framed_image_with_3_columns_text_and_call_to_action.json
#
# verificate al 276
# crowd-blocks/2_rows_-_2_columns_image_left_and_text_right.json
#
# verificate al 277
# crowd-blocks/3_columns_-_images_with_boxed_text_above.json
#
# verificate al 278
# nessa-blocks/50-50_with_cta.json
#
# verificate al 279
# nessa-blocks/1_overlapping_image_on_left_with_text_on_right.json
#
# verificate al 280
# nessa-blocks/2_text_columns_with_centered_image.json
#
# verificate al 281
# nessa-blocks/multiple_links_with_images_and_call_to_action.json
#
# verificate al 282
# nessa-blocks/2_flipping_cards_with.json
#
# verificate al 283
# nessa-blocks/text_with_numerals_with_title_and_image.json
#
# verificate al 284
# nessa-blocks/listing_with_flipping_images_and_cta.json
#
# verificate al 285
# nessa-blocks/2_text_columns_with_centerd_image.json
#
# nessa-blocks/2_text_columns_with_centerd_image.json;velvet-blocks/1_text_column_left_and_1_image_column_right.json;12;12;1;8.3;8.3
# verificate al 286
# nessa-blocks/1_text_column_left_&_image_right.json
#
# verificate al 287
# nessa-blocks/4_links_in_4_rows.json
#
# verificate al 288
# nessa-blocks/announcement_bar.json
#
# verificate al 289
# nessa-blocks/text_left_with_asymmetric_images.json
#
# verificate al 290
# nessa-blocks/3_text_columns_with_images.json
#
# nessa-blocks/3_text_columns_with_images.json;nomade-blocks/2_columns_images_with_title_and_paragraph.json;21;16;1;4.8;6.2
# nessa-blocks/3_text_columns_with_images.json;velvet-blocks/1_text_column_left_and_1_image_column_right.json;21;12;1;4.8;8.3
# verificate al 291
# nessa-blocks/image_left_-_text_right.json
#
# verificate al 292
# nessa-blocks/1_text_column_on_right_with_image_on_left.json
#
# verificate al 293
# nessa-blocks/3_flipping_cards_with_cta.json
#
# verificate al 294
# nessa-blocks/4_asymmetrical_text_rows.json
#
# verificate al 295
# nessa-blocks/quick_links_on_right_image_on_left.json
#
# verificate al 296
# nessa-blocks/big_text_-_call_to_action.json
#
# verificate al 297
# nessa-blocks/title_with_image_on_left_and_text_rows_on_right.json
#
# verificate al 298
# nessa-blocks/4_text_columns_with_numerals.json
#
# verificate al 299
# niko-blocks/title_with_6_images_and_call_to_action.json
#
# verificate al 300
# niko-blocks/2_columns_with_text_image_and_link.json
#
# verificate al 301
# niko-blocks/title_with_4_text_columns_top_and_image_bottom.json
#
# verificate al 302
# niko-blocks/tabs_with_call_to_action.json
#
# verificate al 303
# niko-blocks/background_image_with_title_text_on_top_and_4_rows_with_call_to_action.json
#
# niko-blocks/background_image_with_title_text_on_top_and_4_rows_with_call_to_action.json;elise-blocks/fullscreen_image_with_title_and_3_columns.json;17;11;1;5.9;9.1
# niko-blocks/background_image_with_title_text_on_top_and_4_rows_with_call_to_action.json;lovely-blocks/fullscreen_background_image_-_text_over_and_lines.json;17;7;1;5.9;14.3
# verificate al 304
# niko-blocks/title_with_3_text_columns.json
#
# verificate al 305
# niko-blocks/title_left_and_image_with_text_and_call_to_action_right.json
#
# verificate al 306
# niko-blocks/text_with_tabs_and_background_image.json
#
# verificate al 307
# niko-blocks/title_with_call_to_action_and_timeline.json
#
# verificate al 308
# niko-blocks/title_with_tabs.json
#
# verificate al 309
# niko-blocks/text_left_and_tabs_with_call_to_action_right.json
#
# verificate al 310
# niko-blocks/3_columns_with_text_and_links.json
#
# verificate al 311
# niko-blocks/4_columns_with_images.json
#
# verificate al 312
# niko-blocks/image_left_and_text_with_call_to_action_right.json
#
# verificate al 313
# niko-blocks/3_images_with_display_text.json
#
# verificate al 314
# niko-blocks/3_columns_with_image_and_text.json
#
# verificate al 315
# niko-blocks/text_with_countdown_and_call_to_action_left_and_2_columns_with_image_text_and_link_right.json
#
# verificate al 316
# niko-blocks/display_text_with_links_and_image_left_and_image_with_text_and_call_to_action_right.json
#
# verificate al 317
# niko-blocks/4_rows_with_text.json
#
# verificate al 318
# niko-blocks/6_columns_with_image_text_and_call_to_action.json
#
# verificate al 319
# nomade-blocks/multiple_images_on_right_with_title_and_paragraph.json
#
# verificate al 320
# nomade-blocks/3_columns_asymmetrical_with_title.json
#
# verificate al 321
# nomade-blocks/title_with_boxed_video_and_description_centered.json
#
# verificate al 322
# nomade-blocks/2_columns_images_with_title_and_paragraph.json
#
# nomade-blocks/2_columns_images_with_title_and_paragraph.json;velvet-blocks/1_text_column_left_and_1_image_column_right.json;16;12;1;6.2;8.3
# verificate al 323
# nomade-blocks/1_call_to_action_with_display_text_and_2_images.json
#
# verificate al 324
# nomade-blocks/title_with_2_columns_with_image_title_and_call_to_action.json
#
# verificate al 325
# nomade-blocks/1_image_with_quote_and_call_to_action.json
#
# verificate al 326
# nomade-blocks/3_rows_boxed_videos_with_call_to_action.json
#
# verificate al 327
# nomade-blocks/_1_image_with_display_text_and_paragraph_with_2_links.json
#
# verificate al 328
# nomade-blocks/display_text_with_overlaping_video.json
#
# verificate al 329
# nomade-blocks/title_with_image_4_rows_text_with_one_call_to_action.json
#
# verificate al 330
# nomade-blocks/2_rows_and_2_columns_sectioned_with_title.json
#
# verificate al 331
# nomade-blocks/3_columns_with_title_description_image_and_link.json
#
# verificate al 332
# nomade-blocks/multiple_images_collage_with_text_on_right.json
#
# verificate al 333
# nomade-blocks/fullscreen_background_video_with_display_title_and_links.json
#
# verificate al 334
# nomade-blocks/title_with_3_featured_videos.json
#
# verificate al 335
# nomade-blocks/asymmetrical_grid_with_title_description_and_call_to_action.json
#
# verificate al 336
# nomade-blocks/1_image_on_left_with_accent_background_and_2_columns_text.json
#
# verificate al 337
# nomade-blocks/3_columns_text_with_social_links.json
#
# verificate al 338
# nomade-blocks/intro_text_in_center_with_2_images_and_paragraph.json
#
# verificate al 339
# kaya-blocks/display_text_with_2_images.json
#
# verificate al 340
# kaya-blocks/2_columns_with_links_on_sides_and_centered_text_with_call_to_action.json
#
# verificate al 341
# kaya-blocks/text_left_and_call_to_action_right_with_links_bottom.json
#
# kaya-blocks/text_left_and_call_to_action_right_with_links_bottom.json;faro-blocks/fullscreen_image_with_display_text.json;10;9;1;10.0;11.1
# verificate al 342
# kaya-blocks/image_with_text_left_and_full_height_image_right.json
#
# kaya-blocks/image_with_text_left_and_full_height_image_right.json;kaya-blocks/2_full_height_images_with_call_to_action.json;6;14;1;16.7;7.1
# verificate al 343
# kaya-blocks/3_image_columns_with_links.json
#
# verificate al 344
# kaya-blocks/fullscreen_image_with_text.json
#
# kaya-blocks/fullscreen_image_with_text.json;milea-blocks/fullscreen_background_image_with_title_and_arrow_down.json;5;5;1;20.0;20.0
# verificate al 345
# kaya-blocks/call_to_action_with_title_on_top_and_2_columns_with_tabs.json
#
# kaya-blocks/call_to_action_with_title_on_top_and_2_columns_with_tabs.json;velvet-blocks/1_call_to_action_and_3_columns_with_image_and_title.json;9;12;1;11.1;8.3
# verificate al 346
# kaya-blocks/images_on_sides_with_centered_text.json
#
# verificate al 347
# kaya-blocks/title_with_multiple_images_asymmetrical_rows.json
#
# verificate al 348
# kaya-blocks/3_rows_with_title_and_call_to_actions.json
#
# verificate al 349
# kaya-blocks/text_with_call_to_action_left_and_tabs_right.json
#
# verificate al 350
# kaya-blocks/image_with_2_text_columns_left_and_2_images_with_quote_right.json
#
# verificate al 351
# kaya-blocks/3_images_left_with_display_text_and_2_text_columns_with_call_to_action_right.json
#
# verificate al 352
# kaya-blocks/4_text_columns_with_images_on_hover.json
#
# verificate al 353
# kaya-blocks/title_with_3_image_columns_with_text.json
#
# verificate al 354
# kaya-blocks/text_with_tabs_left_and_logos_with_call_to_action_right.json
#
# verificate al 355
# kaya-blocks/2_full_height_images_with_call_to_action.json
#
# verificate al 356
# kaya-blocks/title_with_call_to_action_and_3_text_columns_right.json
#
# verificate al 357
# kaya-blocks/5_rows_with_title_images_and_call_to_action.json
#
# verificate al 358
# kaya-blocks/centered_text_image..json
#
# kaya-blocks/centered_text_image..json;kaya-blocks/centered_text_image.json;6;6;3;50.0;50.0
# verificate al 359
# kaya-blocks/centered_text_image.json
#
# verificate al 360
# verso-blocks/2_columns_-_image_background_with_text_over_and_title_asymmetrical.json
#
# verificate al 361
# verso-blocks/fullscreen_background_image_with_overlapped_image_and_call_to_action.json
#
# verificate al 362
# verso-blocks/2_columns_-_text_with_description_and_image_with_call_to_action.json
#
# verificate al 363
# verso-blocks/big_video_with_2_text_columns_and_call_to_action.json
#
# verificate al 364
# verso-blocks/2_images_with_text_left_and_text_with_call_to_action_right.json
#
# verificate al 365
# verso-blocks/5_columns_-_image_with_text_and_title_with_link.json
#
# verificate al 366
# verso-blocks/centered_image_with_title_and_keywords.json
#
# verificate al 367
# verso-blocks/display_text_with_image_at_the_top_and_text_with_call_to_action_at_the_bottom.json
#
# verificate al 368
# verso-blocks/1_image_-_display_text_with_paragraph_left_and_text_right.json
#
# verificate al 369
# verso-blocks/3_text_columns_in_asymmetrical_compositions.json
#
# verificate al 370
# verso-blocks/text_with_image_left_and_image_with_accent_color_right.json
#
# verificate al 371
# verso-blocks/2_cards_-_title_with_paragraph_and_call_to_action.json
#
# verificate al 372
# verso-blocks/multiple_mosaic_images_with_call_to_action_and_title.json
#
# verificate al 373
# verso-blocks/text_left_and_image_with_quote_right.json
#
# verificate al 374
# verso-blocks/4_categories_with_images_and_call_to_action_at_the_bottom.json
#
# verificate al 375
# verso-blocks/3_images_with_display_text.json
#
# verificate al 376
# verso-blocks/3_columns_-_text_list_with_image_on_right_and_description.json
#
# verificate al 377
# verso-blocks/2_columns_-_images_with_text_and_social_media_with_accent_color.json
#
# verificate al 378
# verso-blocks/3_rows_-_image_with_text_asymmetrical.json
#
# verificate al 379
# verso-blocks/multiple_images_collage_and_centered_display_text.json
#
# verificate al 380
# osaka-blocks/1_link_-_3_images_right_with_text_left.json
#
# verificate al 381
# osaka-blocks/1_link_-_2_text_colomns_with_image.json
#
# verificate al 382
# osaka-blocks/framed_video_with_title.json
#
# verificate al 383
# osaka-blocks/1_link_-_1_image_left_with_text_card_and_right_text.json
#
# verificate al 384
# osaka-blocks/1_link_-_boxed_2_column_text.json
#
# verificate al 385
# osaka-blocks/3_links_-_3_columns_with_image_and_text.json
#
# verificate al 386
# osaka-blocks/1_link_-_boxed_image_with_text_right.json
#
# verificate al 387
# osaka-blocks/1_link_-_1_image_with_text_card.json
#
# verificate al 388
# osaka-blocks/title_and_text_with_3_images.json
#
# verificate al 389
# osaka-blocks/1_link_-_full_width_image_with_boxed_text.json
#
# verificate al 390
# osaka-blocks/3_links-__title_with_1_image_right.json
#
# verificate al 391
# osaka-blocks/1_link_-_3_columns_with_image_and_text.json
#
# verificate al 392
# osaka-blocks/3_links_-_3_images_with_overline.json
#
# verificate al 393
# osaka-blocks/1_link_-_image_left_with_text_right.json
#
# verificate al 394
# osaka-blocks/2_links_-_text_cards_with_image.json
#
# verificate al 395
# osaka-blocks/2_columns_-_title_centered_and_2_columns_text.json
#
# verificate al 396
# osaka-blocks/1_link_-_image_right_with_text_left.json
#
# verificate al 397
# osaka-blocks/1_link_-_card_left_with_text_right.json
#
# verificate al 398
# osaka-blocks/1_link_-_full_screen_image_with_boxed_text.json
#
# osaka-blocks/1_link_-_full_screen_image_with_boxed_text.json;cube-blocks/full_screen_image_with_2_images_and_text_with_link.json;8;6;1;12.5;16.7
# osaka-blocks/1_link_-_full_screen_image_with_boxed_text.json;faro-blocks/fullscreen_image_with_display_text.json;8;9;1;12.5;11.1
# osaka-blocks/1_link_-_full_screen_image_with_boxed_text.json;velvet-blocks/fullscreen_image_with_display_text_left_and_3_call_to_actions_right.json;8;14;1;12.5;7.1
# verificate al 399
# osaka-blocks/multiple_links_-_boxed_text.json
#
# verificate al 400
# elise-blocks/2_rows_-_display_text_left_with_image_right_and_image_left_with_text_right.json
#
# verificate al 401
# elise-blocks/1_image_with_display_text_and_1_text_column_left_and_1_text_column_right.json
#
# verificate al 402
# elise-blocks/1_big_image_with_call_to_action_left_and_2_small_images_with_call_to_action_right.json
#
# verificate al 403
# elise-blocks/image_left_with_boxed_text_and_tesxt_with_call_to_action_right.json
#
# verificate al 404
# elise-blocks/full_weight_image_on_the_top_and_2_text_columns_with_boxed_call_to_actions_right.json
#
# verificate al 405
# elise-blocks/fullscreen_image_with_title_and_3_columns.json
#
# elise-blocks/fullscreen_image_with_title_and_3_columns.json;lovely-blocks/fullscreen_background_image_-_text_over_and_lines.json;11;7;1;9.1;14.3
# verificate al 406
# elise-blocks/2_autoplaying_videos_with_centered_display_text_and_call_to_action.json
#
# verificate al 407
# elise-blocks/4_columns_with_text_on_the_top_and__image_on_the_bottom.json
#
# verificate al 408
# elise-blocks/display_text_with_call_to_action_and_4_images.json
#
# verificate al 409
# elise-blocks/4_images_on_the_top_and_display_test_with_call_to_action_on_the_bottom.json
#
# verificate al 410
# elise-blocks/full_hight_image_left_and_boxed_test_with_call_to_acrion.json
#
# elise-blocks/full_hight_image_left_and_boxed_test_with_call_to_acrion.json;elise-blocks/full_height_image_left_and_2_small_images_with_call_to_anction_right.json;11;17;1;9.1;5.9
# verificate al 411
# elise-blocks/2_rows_-_image_with_number_and_paragraph.json
#
# verificate al 412
# elise-blocks/2_columns_-_title_with_display_text_left_and_subtitle_with_paragraph_right.json
#
# verificate al 413
# elise-blocks/full_height_image_left_and_centred_display_text_with_paragraph_right.json
#
# elise-blocks/full_height_image_left_and_centred_display_text_with_paragraph_right.json;faro-blocks/title_with_boxed_text_and_call_to_action_and_image.json;5;7;1;20.0;14.3
# verificate al 414
# elise-blocks/full_height_image_left_and_2_small_images_with_call_to_anction_right.json
#
# verificate al 415
# elise-blocks/3_columns_-_text_with_call_to_acton_left_and_2_images_with_text_right.json
#
# elise-blocks/3_columns_-_text_with_call_to_acton_left_and_2_images_with_text_right.json;elise-blocks/1_text_column_left_and_4_rows_with_image_and_call_to_action_right.json;14;27;1;7.1;3.7
# verificate al 416
# elise-blocks/1_text_column_left_and_4_rows_with_image_and_call_to_action_right.json
#
# verificate al 417
# elise-blocks/text_with_call_to_action_left_and_2_images_right.json
#
# verificate al 418
# milea-blocks/2_rows_-_2_featured_images_with_title_and_4_columns_of_images.json
#
# verificate al 419
# milea-blocks/2_images_on_sides_and_big_paragraph_with_call_to_action.json
#
# verificate al 420
# milea-blocks/2_rows_-_image_with_title_paragraph_and_image_with_lines.json
#
# milea-blocks/2_rows_-_image_with_title_paragraph_and_image_with_lines.json;fiji-blocks/3_columns_-_boxed_text_on_sides_and_1_image_at_center.json;13;12;1;7.7;8.3
# verificate al 421
# milea-blocks/2_images_with_2_columns_text_and_title.json
#
# verificate al 422
# milea-blocks/multiple_images_with_text_in_the_left_and_call_to_action.json
#
# verificate al 423
# milea-blocks/2_columns_with_line_and_title.json
#
# verificate al 424
# milea-blocks/title_and_2_columns_paragraph_with_call_to_action_and_1_image.json
#
# verificate al 425
# milea-blocks/featured_image_with_title_and_link_and_3_rows_images_with_titles.json
#
# verificate al 426
# milea-blocks/title_with_5_rows_title_links_and_numbers_and_1_image_boxed.json
#
# verificate al 427
# milea-blocks/boxed_text_accent_color_with_text_and_image_overlapping_and_call_to_action.json
#
# verificate al 428
# milea-blocks/3_columns_text_links_with_dividers_and_social_links.json
#
# verificate al 429
# milea-blocks/fullscreen_background_image_with_title_and_arrow_down.json
#
# verificate al 430
# milea-blocks/4_columns_-__3_text_links_and_1_featured_text_link.json
#
# verificate al 431
# milea-blocks/image_background_with_accent_color_in_right_and_text_left_with_call_to_action.json
#
# verificate al 432
# milea-blocks/framed_video_on_top_left_corner_with_title.json
#
# verificate al 433
# milea-blocks/title_with_line_-_2_text_columns_and_1_image.json
#
# verificate al 434
# milea-blocks/background_accent-_multiple_images_and_text.json
#
# verificate al 435
# milea-blocks/split_screen_-_links_and_image_on_left_and_full_height_image_on_right.json
#
# verificate al 436
# milea-blocks/side_images_with_title_and_centered_text_with_call_to_action.json
#
# verificate al 437
# milea-blocks/title_with_3_images_columns_and_title_with_border.json
#
# verificate al 438
# cube-blocks/5_rows_of_text_and_call_to_action.json
#
# verificate al 439
# cube-blocks/title_with_call_to_action_on_the_top_and_3_images_with_text_in_the_bottom.json
#
# verificate al 440
# cube-blocks/full_screen_image_with_2_images_and_text_with_link.json
#
# cube-blocks/full_screen_image_with_2_images_and_text_with_link.json;faro-blocks/fullscreen_image_with_display_text.json;6;9;1;16.7;11.1
# cube-blocks/full_screen_image_with_2_images_and_text_with_link.json;velvet-blocks/fullscreen_image_with_display_text_left_and_3_call_to_actions_right.json;6;14;1;16.7;7.1
# verificate al 441
# cube-blocks/text_column_with_link_on_the_top_and_3_images_with_titles_on_the_bottom.json
#
# verificate al 442
# cube-blocks/2_rows_of_3_cards_with_image_and_text.json
#
# verificate al 443
# cube-blocks/text_with_link_left_and_image_with_5_links_right.json
#
# verificate al 444
# cube-blocks/image_left_and_text_with_call_to_action_right.json
#
# verificate al 445
# cube-blocks/1_big_image_left_and_3_small_images_with_title_and_call_to_action_right_.json
#
# verificate al 446
# cube-blocks/image_with_title_left_and_text_with_link_right.json
#
# verificate al 447
# cube-blocks/text_with_title_left_and_small_image_with_6_links_right.json
#
# verificate al 448
# cube-blocks/2_columns_with_display_text.json
#
# verificate al 449
# cube-blocks/text_with_1_link_left_and_column_with_links_centered_and_link_right.json
#
# verificate al 450
# cube-blocks/display_text_with_link_left_and_image_right.json
#
# verificate al 451
# cube-blocks/mosaic_of_2_rows_of_3_images_with_titles.json
#
# verificate al 452
# cube-blocks/listing_of_3_cards_with_text_and_image.json
#
# verificate al 453
# cube-blocks/video_on_the_top_and_text_with_link_on_the_bottom.json
#
# verificate al 454
# cube-blocks/mosaic_of_2_rows_of_2_images_with_titles_overlaped.json
#
# verificate al 455
# cube-blocks/text_column_with_image_left_and_text_with_image_right.json
#
# verificate al 456
# cube-blocks/text_with_link_on_the_top_and_video_on_the_bottom.json
#
# verificate al 457
# cube-blocks/text_with_small_title_left_and_image_with_text_right.json
#
# verificate al 458
# porto-blocks/2_columns_-_social_links_and_framed_title_paragraph_with_call_to_action.json
#
# verificate al 459
# porto-blocks/3_columns_-_one_line_text_with_decoration.json
#
# verificate al 460
# porto-blocks/3_columns_-_display_text_with_title_and_paragraph_and_lines.json
#
# verificate al 461
# porto-blocks/centered_title_and_2_image_columns_with_framed_text.json
#
# verificate al 462
# porto-blocks/accent_background_with_quote_and_framed_video_centered.json
#
# verificate al 463
# porto-blocks/_3_columns_-_text_list.json
#
# verificate al 464
# porto-blocks/2_rows_cards_-_framed_title_with_description_and_call_to_action.json
#
# verificate al 465
# porto-blocks/3_columns_-_text_list.json
#
# verificate al 466
# porto-blocks/big_image_with_framed_title_and_call_to_action.json
#
# verificate al 467
# porto-blocks/4_columns_-_title_and_paragraph.json
#
# verificate al 468
# porto-blocks/fullscreen_background_image_with_centered_title_and_links.json
#
# verificate al 469
# porto-blocks/framed_video_on_left_and_text_on_right_with_links.json
#
# verificate al 470
# porto-blocks/2_columns_-_background_image_with_text_over_and_call_to_action.json
#
# verificate al 471
# porto-blocks/text_on_left_and_video_on_right_with_accent_background.json
#
# verificate al 472
# porto-blocks/centered_title_and_3_image_columns_with_boxed_title.json
#
# verificate al 473
# porto-blocks/3_columns_-_title_with_overline_and_paragraph.json
#
# verificate al 474
# porto-blocks/1_image_-_2_columns_title_with_paragraph_and_links.json
#
# verificate al 475
# porto-blocks/3_text_columns_-_title_and_paragraph.json
#
# verificate al 476
# porto-blocks/1_image_-_title_and_description_with_big_paragraph.json
#
# verificate al 477
# porto-blocks/fullscreen_background_image_with_multiple_text_columns_and_call_to_action.json
#
# porto-blocks/fullscreen_background_image_with_multiple_text_columns_and_call_to_action.json;velvet-blocks/fullscreen_image_with_2_text_columns_and_3_call_to_actions.json;17;14;1;5.9;7.1
# verificate al 478
# lyra-blocks/3_columns_-_full_haight_image_left_and_3_call_to_actions.json
#
# verificate al 479
# lyra-blocks/call_to_action_and_2_columns_with_image_and_text.json
#
# lyra-blocks/call_to_action_and_2_columns_with_image_and_text.json;lyra-blocks/centred_image_with_display_and_multiple_links_right.json;10;7;1;10.0;14.3
# verificate al 480
# lyra-blocks/text_with_link_on_left_and_2_images_with_dispay_on_center.json
#
# verificate al 481
# lyra-blocks/2_rows_-_cards_image_with_text.json
#
# verificate al 482
# lyra-blocks/full_haight_image_with_text_and_call_to_action_right_and_1_text_column_left.json
#
# verificate al 483
# lyra-blocks/1_column_-_image_left_with_vertical_steps.json
#
# verificate al 484
# lyra-blocks/1_image_-_text_with_call_to_action_right_and_text_left.json
#
# verificate al 485
# lyra-blocks/image_left_with_centered_display_and_text_with_call_to_action_right.json
#
# verificate al 486
# lyra-blocks/2_full_height_images_with_titles.json
#
# verificate al 487
# lyra-blocks/2_text_columns_with_call_to_actions_and_image_right.json
#
# verificate al 488
# lyra-blocks/1_image_-_text_left_with_call_to_action.json
#
# verificate al 489
# lyra-blocks/multiple_images_-_text_left_and_text_with_link_right.json
#
# verificate al 490
# lyra-blocks/image_with_text_left_and_full_height_image_with_text_right.json
#
# verificate al 491
# lyra-blocks/fullscreen_image_with_text_left_and_boxed_image_with_text_right.json
#
# verificate al 492
# lyra-blocks/2_columns_-_big_image_with_call_to_action_right_and_small_image_with_call_to_action_on_right.json
#
# verificate al 493
# lyra-blocks/2_images_with_2_text_columns_in_asymmetric_composition.json
#
# verificate al 494
# lyra-blocks/call_to_action_right_with_title_and_paragraph.json
#
# verificate al 495
# lyra-blocks/2_columns_-_title_left_with_link.json
#
# verificate al 496
# lyra-blocks/centred_image_with_display_and_multiple_links_right.json
#
# verificate al 497
# lyra-blocks/centred_image_with_centred_display_text.json
#
# verificate al 498
# faro-blocks/1_video_with_2_display_texts.json
#
# verificate al 499
# faro-blocks/3_rows_with_image_and_text.json
#
# verificate al 500
# faro-blocks/full_height_and_text_with_call_to_action.json
#
# verificate al 501
# faro-blocks/3_columns_-_images_with_text.json
#
# verificate al 502
# faro-blocks/full_height_image_with_call_to_action_and_image_with_call_to_action.json
#
# faro-blocks/full_height_image_with_call_to_action_and_image_with_call_to_action.json;faro-blocks/1_text_column_with_call_to_action_left_and_2_images_right.json;11;11;1;9.1;9.1
# faro-blocks/full_height_image_with_call_to_action_and_image_with_call_to_action.json;velvet-blocks/fullscreen_image_with_display_text_left_and_3_call_to_actions_right.json;11;14;1;9.1;7.1
# verificate al 503
# faro-blocks/1_call_to_action_column_left_and_display_with_image_right.json
#
# faro-blocks/1_call_to_action_column_left_and_display_with_image_right.json;faro-blocks/1_image_with_display_text_and_call_to_action.json;16;9;1;6.2;11.1
# faro-blocks/1_call_to_action_column_left_and_display_with_image_right.json;faro-blocks/display_text_with_texture_in_background.json;16;3;1;6.2;33.3
# verificate al 504
# faro-blocks/1_text_column_with_call_to_action_left_and_2_images_right.json
#
# faro-blocks/1_text_column_with_call_to_action_left_and_2_images_right.json;faro-blocks/1_text_column_with_call_to_action_and_2_text_columns_with_image_right.json;11;20;1;9.1;5.0
# faro-blocks/1_text_column_with_call_to_action_left_and_2_images_right.json;faro-blocks/full_height_image_and_call_to_action_left_and_text_column_right.json;11;10;1;9.1;10.0
# verificate al 505
# faro-blocks/2_columns_with_image_and_call_to_action_and_1_full_heigh_image_with_text_and_call_to_action.json
#
# verificate al 506
# faro-blocks/1_image_with_display_text_and_call_to_action.json
#
# faro-blocks/1_image_with_display_text_and_call_to_action.json;faro-blocks/display_text_with_texture_in_background.json;9;3;1;11.1;33.3
# verificate al 507
# faro-blocks/3_columns_-_image_and_call_to_action.json
#
# verificate al 508
# faro-blocks/display_text_with_texture_in_background.json
#
# verificate al 509
# faro-blocks/1_image_with_display_text_and_2_text_columns_with_call_to_actions.json
#
# faro-blocks/1_image_with_display_text_and_2_text_columns_with_call_to_actions.json;faro-blocks/fullscreen_image_with_display_text.json;15;9;1;6.7;11.1
# verificate al 510
# faro-blocks/fullscreen_image_with_title_and_call_to_action.json
#
# verificate al 511
# faro-blocks/fullscreen_image_with_display_text.json
#
# faro-blocks/fullscreen_image_with_display_text.json;velvet-blocks/fullscreen_image_with_display_text_left_and_3_call_to_actions_right.json;9;14;1;11.1;7.1
# verificate al 512
# faro-blocks/1_text_column_left_with_1_image_in_middle_and_1_text_column_with_call_to_action.json
#
# verificate al 513
# faro-blocks/1_text_column_with_call_to_action_and_2_text_columns_with_image_right.json
#
# faro-blocks/1_text_column_with_call_to_action_and_2_text_columns_with_image_right.json;faro-blocks/full_height_image_and_call_to_action_left_and_text_column_right.json;20;10;1;5.0;10.0
# verificate al 514
# faro-blocks/image_with_text_block_left_and_image_with_text_right.json
#
# verificate al 515
# faro-blocks/3_text_columns.json
#
# verificate al 516
# faro-blocks/full_height_image_and_call_to_action_left_and_text_column_right.json
#
# verificate al 517
# faro-blocks/title_with_boxed_text_and_call_to_action_and_image.json
#
# verificate al 518
# june-blocks/full_height_image_with_text_left_and_small_image_with_text_right.json
#
# verificate al 519
# june-blocks/4_cards_with_test_and_image.json
#
# verificate al 520
# june-blocks/2_cards_-_image_with_overlay_text_and_call_to_action.json
#
# verificate al 521
# june-blocks/2_cards_with_image_with_text_left_and_tesxt_with_image_and_call_to_action_right.json
#
# verificate al 522
# june-blocks/3_images_with_accent_color_left_and_multiple_links_right.json
#
# verificate al 523
# june-blocks/text_column_left_and_image_right.json
#
# verificate al 524
# june-blocks/multiple_images_with_centred_text_and_call_to_action.json
#
# verificate al 525
# june-blocks/3_images_with_accent_color_and_display_text.json
#
# verificate al 526
# june-blocks/multiple_images_with_multiple_links.json
#
# verificate al 527
# june-blocks/2_images_with_overlay_text_and_3_text_columns.json
#
# verificate al 528
# june-blocks/3_fliped_card_with_image_and_text.json
#
# verificate al 529
# june-blocks/text_block_with_3_images_and_3_columns_with_image_and_text.json
#
# verificate al 530
# june-blocks/video_with_call_to_action.json
#
# verificate al 531
# june-blocks/3_columns_-_image_with_boxed_text_and_call_to_action.json
#
# verificate al 532
# june-blocks/title_with_multiple_images_and_text.json
#
# verificate al 533
# june-blocks/multiple_images_left_and_text_column_with_call_to_action_right.json
#
# verificate al 534
# june-blocks/2_cards_with_boxed_text_and_image_and_call_to_action.json
#
# verificate al 535
# june-blocks/full_height_image_left_and_2_small_images_with_text_right.json
#
# verificate al 536
# june-blocks/3_images_with_display_text.json
#
# verificate al 537
# june-blocks/fullscreen_image_with_boxed_text.json
#
# verificate al 538
# velvet-blocks/3_images_with_text_and_1_call_to_action.json
#
# verificate al 539
# velvet-blocks/3_rows_with_image_and_text.json
#
# verificate al 540
# velvet-blocks/1_text_column_left_and_1_image_column_right.json
#
# verificate al 541
# velvet-blocks/image_with_link_left_and_text_block_right.json
#
# verificate al 542
# velvet-blocks/fullscreen_image_with_display_text_left_and_3_call_to_actions_right.json
#
# verificate al 543
# velvet-blocks/3_small_images_and_3_call_to_actions.json
#
# verificate al 544
# velvet-blocks/full_weight_image_with_boxed_text.json
#
# verificate al 545
# velvet-blocks/full_height_image_and_text_with_call_to_action_right.json
#
# verificate al 546
# velvet-blocks/3_images_with_text.json
#
# verificate al 547
# velvet-blocks/4_images_and_boxed_text.json
#
# verificate al 548
# velvet-blocks/image_left_and_1_text_block_right.json
#
# verificate al 549
# velvet-blocks/3_text_columns_with_call_to_action.json
#
# verificate al 550
# velvet-blocks/1_call_to_action_and_3_columns_with_image_and_title.json
#
# verificate al 551
# velvet-blocks/image_with_text_left_and_text_with_call_to_action_right.json
#
# verificate al 552
# velvet-blocks/quote_text_left_and_3_rows_with_image_and_text_right.json
#
# verificate al 553
# velvet-blocks/boxed_text_with_call_to_action_left_and_image_with_link_right.json
#
# verificate al 554
# velvet-blocks/autoplay_video_with_title.json
#
# verificate al 555
# velvet-blocks/fullscreen_image_with_2_text_columns_and_3_call_to_actions.json
#
# verificate al 556
# velvet-blocks/3_columns_with_image_and_text.json
#
# verificate al 557
# lovely-blocks/asymmetric_grid_images_with_links_over.json
#
# verificate al 558
# lovely-blocks/3_columns_-_images_masonry_with_title.json
#
# verificate al 559
# lovely-blocks/2_columns_-_video_left_and_title_on_right.json
#
# verificate al 560
# lovely-blocks/2_columns_-_title_with_line_and_grid_of_links.json
#
# verificate al 561
# lovely-blocks/text_list_on_left_with_1_image_right.json
#
# verificate al 562
# lovely-blocks/full_width_background_image_-_title_and_paragraph_on_right.json
#
# verificate al 563
# lovely-blocks/2_columns_-_one_small_and_one_big_paragraph.json
#
# verificate al 564
# lovely-blocks/framed_text_card_with_image_on_left.json
#
# verificate al 565
# lovely-blocks/multiple_images_collage_with_text_and_call_to_action.json
#
# verificate al 566
# lovely-blocks/3_columns_-_framed_text_with_call_to_action.json
#
# verificate al 567
# lovely-blocks/big_image_with_text_and_call_to_action_and_social_links.json
#
# verificate al 568
# lovely-blocks/fullscreen_background_image_-_text_over_and_lines.json
#
# verificate al 569
# lovely-blocks/2_columns_-_1_link_on_card_with_text_and_image_on_right.json
#
# verificate al 570
# lovely-blocks/multiple_background_images_-_asymmetric_grid.json
#
# verificate al 571
# lovely-blocks/4_columns_-_images_grid_with_2_call_to_action.json
#
# verificate al 572
# lovely-blocks/1_column_-_text_with_image_left_and_multiple_links.json
#
# verificate al 573
# lovely-blocks/centered_title_with_rounded_image_and_paragraph.json
#
# verificate al 574
# lovely-blocks/text_with_multiple_images_and_call_to_action.json
#
# verificate al 575
# lovely-blocks/2_columns_-_1_image_left_with_link_and_paragraph_on_right.json
#
# verificate al 576
# lovely-blocks/2_columns_-_background_images_with_text_and_call_to_action.json
#
# verificate al 577
# fiji-blocks/2_columns_-_paragraph_and_image_on_left_and_boxed_text_list_on_right.json
#
# verificate al 578
# fiji-blocks/3_image_columns_-_links_with_title.json
#
# verificate al 579
# fiji-blocks/3_columns_-_text_on_left_with_image_and_small_description_with_call_to_action.json
#
# verificate al 580
# fiji-blocks/fullscreen_background_image_with_text_over_on_left_and_right.json
#
# fiji-blocks/fullscreen_background_image_with_text_over_on_left_and_right.json;fiji-blocks/fullscreen_background_image_with_boxed_text_and_call_to_action.json;13;7;1;7.7;14.3
# verificate al 581
# fiji-blocks/6_links_image_grid_-_text_over_image.json
#
# verificate al 582
# fiji-blocks/2_columns_-_image_with_title_and_list_of_multiple_links.json
#
# verificate al 583
# fiji-blocks/framed_background_image_with_boxed_text_list.json
#
# verificate al 584
# fiji-blocks/framed_image_with_text_and_call_to_action_and_boxed_multiple_links.json
#
# verificate al 585
# fiji-blocks/framed_background_image_with_boxed_text_above_the_image.json
#
# verificate al 586
# fiji-blocks/fullscreen_background_image_with_text_over_on_left.json
#
# verificate al 587
# fiji-blocks/title_with_substitle_and_boxed_images_grid.json
#
# verificate al 588
# fiji-blocks/framed_text_and_image.json
#
# verificate al 589
# fiji-blocks/4_columns_-_image_and_text_with_description.json
#
# verificate al 590
# fiji-blocks/video_left_with_framed_image_and_title_on_right.json
#
# verificate al 591
# fiji-blocks/fullscreen_background_image_with_boxed_text_and_call_to_action.json
#
# verificate al 592
# fiji-blocks/3_columns_-_boxed_text_on_sides_and_1_image_at_center.json
#
# verificate al 593
# fiji-blocks/framed_video_and_text.json
#
# verificate al 594
# fiji-blocks/boxed_text_list_with_4_images_asymmetrical_on_the_right.json
#
# verificate al 595
# fiji-blocks/3_columns_-_title_with_boxed_text_in_accent_color.json
#
# verificate al 596
# fiji-blocks/2_columns_-_long_paragraph_with_title.json
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-0febd140513c> in <module>
#      86 data_aprox = {'block_1':ways1,'block_2':ways2,
#      87               'num_elem_1':total_elements1,'num_elem_2':total_elements2,
# ---> 88               'com_elem':com_elements,'percent_1':com_elements1,'percent_2':com_elements2 }
#      89 df_aprox = pd.DataFrame(data_aprox)
#      90 df_aprox = df_aprox.sort_values(['percent_1','percent_2','com_elem',], ascending=False)
#
# NameError: name 'com_elements' is not defined

# %%
data_aprox = {'block_1':ways1,'block_2':ways2, 
              'num_elem_1':total_elements1,'num_elem_2':total_elements2,
              'com_elem':com_elem,'percent_1':percent_1,'percent_2':percent_2 } 
df_aprox = pd.DataFrame(data_aprox) 
df_aprox = df_aprox.sort_values(['percent_1','percent_2','com_elem',], ascending=False)
df_aprox.to_csv('finala_aprox.csv', index=False)

# %%
df_aprox.to_excel('aproxim.xlsx', engine='xlsxwriter', index=False)
